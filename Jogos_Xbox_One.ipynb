# %% [markdown]
# <a href="https://colab.research.google.com/github/DamodaraBarbosa/estudos_data_science/blob/main/Jogos_Xbox_One.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Estudos dataset Xbox One Games**

# %% [markdown]
# Importando dataset

# %%
import pandas as pd

# %%
xbox_one_data = pd.read_csv('xbox_one_games.csv')

# %%
xbox_one_data
# Out:
#       gameid                                          name  \
# 0       5530                                             Q
# 1       5819  Q*bert REBOOTED: The XBOX One @!#?@! Edition
# 2       6951                                    Q.U.B.E. 2
# 3       5561                       Q.U.B.E. Director's Cut
# 4       9781                                         Quake
# ...      ...                                           ...
# 4801    8779                          9 Monkeys of Shaolin
# 4802    6747                                  911 Operator
# 4803    6757                                       99Vidas
# 4804    8867                                  9th Dawn III
# 4805    6441                           'n Verlore Verstand
#
#                                                  web  \
# 0            http://liica.co.jp/contents/q/jp/x.html
# 1                                                NaN
# 2                https://www.toxicgames.co.uk/qube2/
# ...
