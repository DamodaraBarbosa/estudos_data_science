# %% [markdown]
# <a href="https://colab.research.google.com/github/DamodaraBarbosa/estudos_data_science/blob/main/Tabela_Gamepass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tratamento da tabela com os jogos do serviço Xbox Gamepass

# %%
import pandas as pd

# %% [markdown]
# Importando a base de dados

# %%
gamepass_data = pd.read_csv('Game Pass Master List - Master List.csv')

# %% [markdown]
# Tratando a base de dados

# %%
# renomeando as colunas da base de dados

columns = list()

for key, value in gamepass_data.iloc[0].items():
  columns.append(value)

columns
# Out:
# ['Game',
#  'System',
#  'xCloud',
#  'Status',
#  'Added',
#  'Removed',
#  'Months',
#  'Release',
#  'Age',
#  'Metacritic',
#  'Completion',
#  'Genre (Giantbomb)',
#  'Xbox Series X|S',
#  'Owner Notes',
#  'ESRB',
#  'ESRB Content Descriptors',
#  'Public Notes']

# %%
gamepass_data.columns = columns

# %%
gamepass_data.drop(0, inplace = True)

# %%
gamepass_data.head()
# Out:
#                                    Game     System xCloud       Status  \
# 1  S.T.A.L.K.E.R. 2: Heart of Chornobyl  Xbox / PC    Yes  Coming Soon
# 2                          High on Life  Xbox / PC    Yes  Coming Soon
# 3                      Hello Neighbor 2  Xbox / PC    Yes  Coming Soon
# 4            Warhammer 40,000: Darktide  Xbox / PC    Yes  Coming Soon
# 5                             Pentiment  Xbox / PC    Yes  Coming Soon
#
#       Added Removed Months   Release   Age Metacritic Completion  \
# 1  Dec 2022     NaN  -3.19  Dec 2022  0.00        NaN        NaN
# 2  Dec 2022     NaN  -3.35  Dec 2022  0.00        NaN        NaN
# 3  Dec 2022     NaN  -3.12  Dec 2022  0.00        NaN        NaN
# 4  Nov 2022     NaN  -2.93  Nov 2022  0.00        NaN        NaN
# 5  Nov 2022     NaN  -2.43  Nov 2022  0.00        NaN        NaN
#
#                          Genre (Giantbomb) Xbox Series X|S Owner Notes  ESRB  \
# ...

# %%
# convertendo os dados da coluna 'Added' para datetime
gamepass_data['Added'] = pd.to_datetime(gamepass_data['Added'])
gamepass_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1148 entries, 1 to 1148
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Game                      1148 non-null   object
#  1   System                    1148 non-null   object
#  2   xCloud                    554 non-null    object
#  3   Status                    1148 non-null   object
#  4   Added                     1148 non-null   datetime64[ns]
#  5   Removed                   598 non-null    object
#  6   Months                    1148 non-null   object
#  7   Release                   1148 non-null   object
#  8   Age                       1148 non-null   object
#  9   Metacritic                1115 non-null   object
#  10  Completion                1102 non-null   object
#  11  Genre (Giantbomb)         1148 non-null   object
#  12  Xbox Series X|S           163 non-null    object
# ...

# %%
# convertendo a coluna 'Release' de object para datetime

gamepass_data['Release'] = pd.to_datetime(gamepass_data['Release'])

# %%
gamepass_data.sample(5)
# Out:
#                          Game     System          xCloud   Status      Added  \
# 501               DOOM (2016)       Xbox             Yes   Active 2018-08-01
# 1085       Resident Evil Zero       Xbox             NaN  Removed 2017-06-01
# 1065          Mega Coin Squad       Xbox             NaN  Removed 2017-06-01
# 175                   Exo One  Xbox / PC  Touch Controls   Active 2021-11-01
# 1101  Tekken Tag Tournament 2       Xbox             NaN  Removed 2017-06-01
#
#        Removed Months    Release    Age Metacritic Completion  \
# 501        NaN  48.79 2016-05-01   2.24         87       11.5
# 1085  Nov 2018  17.03 2002-11-01  14.57         69       11.5
# 1065  Feb 2019  20.05 2014-08-01   2.80         74          1
# 175        NaN   9.47 2021-11-01   0.00         80          2
# 1101  Aug 2018  14.01 2011-09-01   5.73         83        1.5
#
#                     Genre (Giantbomb) Xbox Series X|S Owner Notes ESRB  \
# ...

# %%
# convertendo a coluna 'Removed' para datetime

gamepass_data['Removed'] = pd.to_datetime(gamepass_data['Removed'])

# %%
gamepass_data.sample(5)
# Out:
#                              Game     System          xCloud   Status  \
# 26   Return to Castle Wolfenstein         PC             NaN   Active
# 422            Minecraft Dungeons  Xbox / PC  Touch Controls   Active
# 62                          OMORI  Xbox / PC             Yes   Active
# 540              Jetpac Refuelled       Xbox  Touch Controls   Active
# 656                      SUPERHOT         PC             NaN  Removed
#
#          Added    Removed Months    Release    Age Metacritic Completion  \
# 26  2022-08-01        NaT   0.49 2001-11-01  20.76         88          8
# 422 2020-05-01        NaT  27.25 2020-05-01   0.00         73          5
# 62  2022-06-01        NaT   2.56 2020-12-01   1.47         87       20.5
# 540 2017-06-01        NaT  63.09 2007-03-01  10.19         73        4.5
# 656 2019-06-01 2021-12-01  30.18 2016-02-01   3.28         83        2.5
#
#                    Genre (Giantbomb) Xbox Series X|S Owner Notes  ESRB  \
# ...

# %%
# convertendo a coluna 'Metacritic' de object para int

for index, metacritic in enumerate(gamepass_data['Metacritic']):
  try:
    gamepass_data.at[index, 'Metacritic'] = float(metacritic)
  except:
    gamepass_data.at[index, 'Metacritic'] = float(metacritic)
    pass

# %%
gamepass_data.sample(5)
# Out:
#                         Game     System          xCloud   Status      Added  \
# 847           Darksiders III  Xbox / PC             Yes  Removed 2019-11-01
# 816  Reigns: Game of Thrones         PC             NaN  Removed 2020-02-01
# 273                   NHL 21       Xbox             NaN   Active 2021-04-01
# 72            Sniper Elite 5  Xbox / PC             Yes   Active 2022-05-01
# 627           Project Winter  Xbox / PC  Touch Controls  Removed 2021-02-01
#
#        Removed Months    Release   Age Metacritic Completion  \
# 847 2020-11-01  11.87 2018-11-01  0.98       40.0         14
# 816 2021-01-01  11.31 2018-10-01  1.34       80.0          2
# 273        NaT  16.70 2020-10-01  0.49       76.0          9
# 72         NaT   3.25 2022-05-01  0.00       81.0          9
# 627 2022-02-01  12.36 2019-02-01  1.99       65.0        9.5
#
#                             Genre (Giantbomb) Xbox Series X|S Owner Notes  \
# ...

# %%
gamepass_data.shape
# Out:
# (1149, 17)

# %%
contador = 0

for metacritic in gamepass_data['Metacritic']:
  if type(metacritic) == str:
    print(metacritic)
    contador += 1

contador
# Out:
# 77
# 1

# %%
gamepass_data.query('Metacritic == "77"')
# Out:
#                                            Game System xCloud   Status  \
# 1148  Dungeons & Dragons: Chronicles of Mystara   Xbox    NaN  Removed
#
#           Added    Removed Months    Release   Age Metacritic Completion  \
# 1148 2017-06-01 2017-08-01   2.47 2013-06-01  3.96         77          2
#
#                                       Genre (Giantbomb) Xbox Series X|S  \
# 1148  Action / Role-Playing / Brawler / Action-Adven...             NaN
#
#      Owner Notes ESRB ESRB Content Descriptors Public Notes
# 1148         NaN  NaN                      NaN          NaN

# %%
gamepass_data.at[1148, 'Metacritic'] = 77.0

# %%
gamepass_data.loc[1148]
# Out:
# Game                                Dungeons & Dragons: Chronicles of Mystara
# System                                                                   Xbox
# xCloud                                                                    NaN
# Status                                                                Removed
# Added                                                     2017-06-01 00:00:00
# Removed                                                   2017-08-01 00:00:00
# Months                                                                   2.47
# Release                                                   2013-06-01 00:00:00
# Age                                                                      3.96
# Metacritic                                                               77.0
# Completion                                                                  2
# Genre (Giantbomb)           Action / Role-Playing / Brawler / Action-Adven...
# ...

# %%
# os gêneros de jogos que aparecem na coluna 'Genre (Giantbomb)'

gamepass_data['Genre (Giantbomb)'].unique()
# Out:
# array(['First-Person Shooter / Action-Adventure', 'First-Person Shooter',
#        'Strategy / Puzzle', 'Action', 'Adventure', 'Action-Adventure',
#        'Role-Playing', 'Adventure / First-Person Shooter', 'Simulation',
#        'Driving/Racing', 'Real-Time Strategy', 'Adventure / Simulation',
#        'Role-Playing / Action-Adventure', 'Adventure / Platformer',
#        'Action / Brawler', 'Action / Role-Playing',
#        'Action / First-Person Shooter', 'Strategy / Role-Playing',
#        'Puzzle', 'Shooter', 'Driving/Racing / Simulation',
#        'Puzzle / Platformer',
#        'Driving/Racing / Shooter / Action-Adventure',
#        'Adventure / Puzzle', 'Educational', 'Action / Platformer',
#        'Music/Rhythm', 'Sports / Tennis', 'Compilation / Puzzle',
#        'Role-Playing / Simulation / Brawler',
#        'Brawler / Action-Adventure', 'Sports / Soccer', 'Strategy',
#        'Brawler', 'Action / Simulation', 'Action / Compilation',
# ...

# %%
# substituindo o elemento 'Role-Playing' para RPG na coluna 'Genre (Giantbomb)'

gamepass_data['Genre (Giantbomb)'] = gamepass_data['Genre (Giantbomb)'].str.replace('Role-Playing', 'RPG')

# %%
# substituindo o elemento 'First-Person Shooter' para FPS na coluna 'Genre (Giantbomb)'

gamepass_data['Genre (Giantbomb)'] = gamepass_data['Genre (Giantbomb)'].str.replace('First-Person Shooter', 'FPS')

# %%
# separando os elementos dos dados da coluna 'Genre (Giantbomb)'

gamepass_data['Genre (Giantbomb)'] = gamepass_data['Genre (Giantbomb)'].str.split(' / ')

# %%
gamepass_data['xCloud'].unique()
# Out:
# array(['Yes', nan, 'Touch Controls'], dtype=object)
