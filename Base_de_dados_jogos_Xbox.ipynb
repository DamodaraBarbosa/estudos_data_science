# %% [markdown]
# <a href="https://colab.research.google.com/github/DamodaraBarbosa/estudos_data_science/blob/main/Base_de_dados_jogos_Xbox.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Estudos dataset Xbox One Games**

# %% [markdown]
# Importando a base de dados

# %%
import pandas as pd
import numpy as np

# %%
data_xbox = pd.read_csv('xbox_one_games.csv')

# %%
data_xbox.head()
# Out:
#    gameid                                          name  \
# 0    5530                                             Q
# 1    5819  Q*bert REBOOTED: The XBOX One @!#?@! Edition
# 2    6951                                    Q.U.B.E. 2
# 3    5561                       Q.U.B.E. Director's Cut
# 4    9781                                         Quake
#
#                                        web            publisher  \
# 0  http://liica.co.jp/contents/q/jp/x.html                liica
# 1                                      NaN                  GPC
# 2      https://www.toxicgames.co.uk/qube2/  Trapped Nerve Games
# 3                    http://qube-game.com/         GRIP Digital
# 4                                      NaN   Bethesda Softworks
#
#                                       developer           release  \
# 0                              liica, OrangeBox      26 June 2015
# 1                              LOOT Interactive  12 February 2016
# 2                                   Toxic Games     13 March 2018
# 3                     Toxic Games, GRIP Digital      24 July 2015
# 4  MachineGames, Nightdive Studios, id Software    19 August 2021
#
#                                            platform                 genre  \
# 0                                          Xbox One                Puzzle
# 1                         Xbox One, Xbox Series X|S                Action
# 2                         Xbox One, Xbox Series X|S    Puzzle, Platformer
# 3                         Xbox One, Xbox Series X|S    Puzzle, Platformer
# 4  Xbox One, Xbox Series X|S, Windows (Windows 10+)  First Person Shooter
#
#          hardware                                          notes  \
# 0  Kinect Enabled                                        ID@Xbox
# 1             NaN                                        ID@Xbox
# 2             NaN                                        ID@Xbox
# 3             NaN                                        ID@Xbox
# 4          64-Bit  xCloud, Xbox Game Pass, Xbox Game Pass for PC
#
#          medium    size completion est          links  \
# 0  Digital only   515MB   80-100 hours  Official site
# 1  Digital only   501MB            NaN            NaN
# 2  Digital only  2.73GB      6-8 hours  Official site
# 3  Digital only  1.28GB      4-5 hours  Official site
# 4  Digital only  1.25GB      2-3 hours            NaN
#
#                                             features
# 0                                                NaN
# 1                                                NaN
# 2                            Xbox One X Enhanced, 4K
# 3                                                NaN
# 4  Smart Delivery, Optimized for Series X|S, 4K, ...

# %%
data_xbox.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4806 entries, 0 to 4805
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   gameid          4806 non-null   int64
#  1   name            4806 non-null   object
#  2   web             4092 non-null   object
#  3   publisher       4223 non-null   object
#  4   developer       4224 non-null   object
#  5   release         4226 non-null   object
#  6   platform        4226 non-null   object
#  7   genre           4223 non-null   object
#  8   hardware        461 non-null    object
#  9   notes           2840 non-null   object
#  10  medium          4226 non-null   object
#  11  size            4225 non-null   object
#  12  completion est  3015 non-null   object
#  13  links           3944 non-null   object
#  14  features        1666 non-null   object
# dtypes: int64(1), object(14)
# memory usage: 563.3+ KB

# %% [markdown]
# Tratando a base de dados

# %%
# a ideia é unir essa base de dados com outra já tratada com jogos que fazem parte do serviço Xbox Gamepass
# as colunas de interesse para esse fim são: 'name', 'publisher', 'developer', 'release', 'platform', 'genre', 'notes', 
# 'medium', 'size', 'features'

# %%
# quanto a coluna 'publisher', percebe-se que em alguns casos há mais de uma publicadora, a ideia é fragmentar tais casos
# para uma futura análise

data_xbox[['publisher']].sample(10)
# Out:
#               publisher
# 225           JanduSoft
# 3628                NaN
# 3441    Plug In Digital
# 2233                NaN
# 3502     Rockstar Games
# 1569       Headup Games
# 3893          505 Games
# 1905                NaN
# 1324         EM Studios
# 68    Xbox Game Studios

# %%
# definindo a nova coluna 'publisher'

data_xbox['publisher'] = data_xbox['publisher'].str.split(', ')
data_xbox.head()
# Out:
#    gameid                                          name  \
# 0    5530                                             Q
# 1    5819  Q*bert REBOOTED: The XBOX One @!#?@! Edition
# 2    6951                                    Q.U.B.E. 2
# 3    5561                       Q.U.B.E. Director's Cut
# 4    9781                                         Quake
#
#                                        web              publisher  \
# 0  http://liica.co.jp/contents/q/jp/x.html                [liica]
# 1                                      NaN                  [GPC]
# 2      https://www.toxicgames.co.uk/qube2/  [Trapped Nerve Games]
# 3                    http://qube-game.com/         [GRIP Digital]
# 4                                      NaN   [Bethesda Softworks]
#
#                                       developer           release  \
# 0                              liica, OrangeBox      26 June 2015
# 1                              LOOT Interactive  12 February 2016
# 2                                   Toxic Games     13 March 2018
# 3                     Toxic Games, GRIP Digital      24 July 2015
# 4  MachineGames, Nightdive Studios, id Software    19 August 2021
#
#                                            platform                 genre  \
# 0                                          Xbox One                Puzzle
# 1                         Xbox One, Xbox Series X|S                Action
# 2                         Xbox One, Xbox Series X|S    Puzzle, Platformer
# 3                         Xbox One, Xbox Series X|S    Puzzle, Platformer
# 4  Xbox One, Xbox Series X|S, Windows (Windows 10+)  First Person Shooter
#
#          hardware                                          notes  \
# 0  Kinect Enabled                                        ID@Xbox
# 1             NaN                                        ID@Xbox
# 2             NaN                                        ID@Xbox
# 3             NaN                                        ID@Xbox
# 4          64-Bit  xCloud, Xbox Game Pass, Xbox Game Pass for PC
#
#          medium    size completion est          links  \
# 0  Digital only   515MB   80-100 hours  Official site
# 1  Digital only   501MB            NaN            NaN
# 2  Digital only  2.73GB      6-8 hours  Official site
# 3  Digital only  1.28GB      4-5 hours  Official site
# 4  Digital only  1.25GB      2-3 hours            NaN
#
#                                             features
# 0                                                NaN
# 1                                                NaN
# 2                            Xbox One X Enhanced, 4K
# 3                                                NaN
# 4  Smart Delivery, Optimized for Series X|S, 4K, ...

# %%
# a ideia para coluna 'developer' é a mesma, pois um mesmo jogo pode ser desenvolvido em conjunto por mais de um estúdio

data_xbox['developer'] = data_xbox['developer'].str.split(', ')
data_xbox.head()
# Out:
#    gameid                                          name  \
# 0    5530                                             Q
# 1    5819  Q*bert REBOOTED: The XBOX One @!#?@! Edition
# 2    6951                                    Q.U.B.E. 2
# 3    5561                       Q.U.B.E. Director's Cut
# 4    9781                                         Quake
#
#                                        web              publisher  \
# 0  http://liica.co.jp/contents/q/jp/x.html                [liica]
# 1                                      NaN                  [GPC]
# 2      https://www.toxicgames.co.uk/qube2/  [Trapped Nerve Games]
# 3                    http://qube-game.com/         [GRIP Digital]
# 4                                      NaN   [Bethesda Softworks]
#
#                                         developer           release  \
# 0                              [liica, OrangeBox]      26 June 2015
# 1                              [LOOT Interactive]  12 February 2016
# 2                                   [Toxic Games]     13 March 2018
# 3                     [Toxic Games, GRIP Digital]      24 July 2015
# 4  [MachineGames, Nightdive Studios, id Software]    19 August 2021
#
#                                            platform                 genre  \
# 0                                          Xbox One                Puzzle
# 1                         Xbox One, Xbox Series X|S                Action
# 2                         Xbox One, Xbox Series X|S    Puzzle, Platformer
# 3                         Xbox One, Xbox Series X|S    Puzzle, Platformer
# 4  Xbox One, Xbox Series X|S, Windows (Windows 10+)  First Person Shooter
#
#          hardware                                          notes  \
# 0  Kinect Enabled                                        ID@Xbox
# 1             NaN                                        ID@Xbox
# 2             NaN                                        ID@Xbox
# 3             NaN                                        ID@Xbox
# 4          64-Bit  xCloud, Xbox Game Pass, Xbox Game Pass for PC
#
#          medium    size completion est          links  \
# 0  Digital only   515MB   80-100 hours  Official site
# 1  Digital only   501MB            NaN            NaN
# 2  Digital only  2.73GB      6-8 hours  Official site
# 3  Digital only  1.28GB      4-5 hours  Official site
# 4  Digital only  1.25GB      2-3 hours            NaN
#
#                                             features
# 0                                                NaN
# 1                                                NaN
# 2                            Xbox One X Enhanced, 4K
# 3                                                NaN
# 4  Smart Delivery, Optimized for Series X|S, 4K, ...

# %%
# quanto a coluna 'release' referente a data de lançamento dos jogos, que é do tipo object, pode ser convertida para datetime
# alguns dados da coluna 'release' estão com valor 'Yesterday', são os mostrados abaixo

data_xbox.query('release == "Yesterday"')
# Out:
#       gameid                              name  web                 publisher  \
# 136    10188               Winter Sports Games  NaN                [Joindots]
# 3053   10168                   Gardener's Path  NaN         [Ratalaika Games]
# 3505   10142  Lacuna - A Sci-Fi Noir Adventure  NaN  [Assemble Entertainment]
#
#                     developer    release                   platform  \
# 136                [Joindots]  Yesterday  Xbox One, Xbox Series X|S
# 3053       [Viridino Studios]  Yesterday  Xbox One, Xbox Series X|S
# 3505  [DigiTales Interactive]  Yesterday  Xbox One, Xbox Series X|S
#
#                          genre hardware notes        medium    size  \
# 136                     Sports      NaN   NaN  Digital only  2.19GB
# 3053                    Puzzle      NaN   NaN  Digital only   348MB
# 3505  Adventure, Point & Click      NaN   NaN  Digital only  2.09GB
#
#      completion est links                                           features
# 136             NaN   NaN  Xbox One X Enhanced, Smart Delivery, Optimized...
# 3053       0-1 hour   NaN                                 Smart Delivery, 4K
# 3505            NaN   NaN                                                NaN

# %%
# com uma rápida pesquisa é possível definir a data de lançamento para os jogos acima:
# Winter Sports Games: https://store.steampowered.com/app/998530/Winter_Sports_Games/
# Gardener's Path: https://www.ratalaikagames.com/games.php?id=gardenerspath/
# Lacuna - Sci-Fi Noir Adventure: https://www.xbox.com/en-US/games/store/lacuna-a-sci-fi-noir-adventure/9MXKTG2JC5SN/

data_xbox.at[136, 'release'] = '24 Dec 2019'
data_xbox.at[3053, 'release'] = '22 Dec 2021'
data_xbox.at[3505, 'release'] = '20 Dec 2021'

# %%
# verificando se os dados foram modificados corretamente

data_xbox.loc[[136, 3053, 3505]]
# Out:
#       gameid                              name  web                 publisher  \
# 136    10188               Winter Sports Games  NaN                [Joindots]
# 3053   10168                   Gardener's Path  NaN         [Ratalaika Games]
# 3505   10142  Lacuna - A Sci-Fi Noir Adventure  NaN  [Assemble Entertainment]
#
#                     developer      release                   platform  \
# 136                [Joindots]  24 Dec 2019  Xbox One, Xbox Series X|S
# 3053       [Viridino Studios]  22 Dec 2021  Xbox One, Xbox Series X|S
# 3505  [DigiTales Interactive]  20 Dec 2021  Xbox One, Xbox Series X|S
#
#                          genre hardware notes        medium    size  \
# 136                     Sports      NaN   NaN  Digital only  2.19GB
# 3053                    Puzzle      NaN   NaN  Digital only   348MB
# 3505  Adventure, Point & Click      NaN   NaN  Digital only  2.09GB
#
#      completion est links                                           features
# 136             NaN   NaN  Xbox One X Enhanced, Smart Delivery, Optimized...
# 3053       0-1 hour   NaN                                 Smart Delivery, 4K
# 3505            NaN   NaN                                                NaN

# %%
# ainda há a presença de valores como 'Today' e 'Tomorrow' que não são de interesse

for release in data_xbox['release'].str.split():
  try:
    if len(release) == 1:
      print(release)
  except:
    pass
# Out:
# ['Today']
# ['Tomorrow']
# ['Today']
# ['Today']

# %%
# localizando-os no dataframe

data_xbox.query('release == "Today" or release == "Tomorrow"')
# Out:
#       gameid                           name  \
# 1194   10172                   In My Shadow
# 1492   10203  Planet Quiz: Learn & Discover
# 3314   10171      Horatio Goes Snowboarding
# 3392   10190         Just a Phrase by POWGI
#
#                                                     web          publisher  \
# 1194                        https://www.inmyshadow.com/        [Overgamez]
# 1492                  https://naptime.games/planetquiz/    [naptime.games]
# 3314  https://www.eastasiasoft.com/games/Horatio-Goe...     [eastasiasoft]
# 3392                                                NaN  [Lightwood Games]
#
#                            developer   release                   platform  \
# 1194                       [Playbae]     Today  Xbox One, Xbox Series X|S
# 1492                 [naptime.games]  Tomorrow  Xbox One, Xbox Series X|S
# 3314  [Infinite State, eastasiasoft]     Today  Xbox One, Xbox Series X|S
# 3392               [Lightwood Games]     Today  Xbox One, Xbox Series X|S
#
#                      genre hardware notes        medium    size  \
# 1194                Puzzle      NaN   NaN  Digital only  1.38GB
# 1492  Educational & Trivia      NaN   NaN  Digital only  1.32GB
# 3314  Sports, Snowboarding      NaN   NaN  Digital only   707MB
# 3392                Puzzle      NaN   NaN  Digital only   381MB
#
#      completion est          links  \
# 1194            NaN  Official site
# 1492            NaN  Official site
# 3314            NaN  Official site
# 3392      1-2 hours            NaN
#
#                                           features
# 1194                                           NaN
# 1492                                           NaN
# 3314      Smart Delivery, Optimized for Series X|S
# 3392  Smart Delivery, Optimized for Series X|S, 4K

# %%
# substiui-se tais valores pelos corretos obtidos por pesquisas
# In My Shadow: https://www.xbox.com/pt-br/games/store/In-My-Shadow/9NSRQQGSFP1N/
# Planet Quiz: Learn & Discover: https://www.xbox.com/pt-BR/games/store/planet-quiz-learn-discover/9N4GZJJR1M84/
# Horatio Goes Snowboarding: https://www.xbox.com/pt-BR/games/store/horatio-goes-snowboarding/9PGBGJQ4FDGC/0010/
# Just a Phrase by POWGI:https://www.xbox.com/pt-br/games/store/just-a-phrase-by-powgi/9pnh58mkp48n/

data_xbox.at[1194, 'release'] = '21 Dec 2021'
data_xbox.at[1492, 'release'] = '22 Dec 2021'
data_xbox.at[3314, 'release'] = '21 Dec 2021'
data_xbox.at[3392, 'release'] = '21 Dec 2021'

data_xbox.loc[[1194, 1492, 3314, 3392]]
# Out:
#       gameid                           name  \
# 1194   10172                   In My Shadow
# 1492   10203  Planet Quiz: Learn & Discover
# 3314   10171      Horatio Goes Snowboarding
# 3392   10190         Just a Phrase by POWGI
#
#                                                     web          publisher  \
# 1194                        https://www.inmyshadow.com/        [Overgamez]
# 1492                  https://naptime.games/planetquiz/    [naptime.games]
# 3314  https://www.eastasiasoft.com/games/Horatio-Goe...     [eastasiasoft]
# 3392                                                NaN  [Lightwood Games]
#
#                            developer      release                   platform  \
# 1194                       [Playbae]  21 Dec 2021  Xbox One, Xbox Series X|S
# 1492                 [naptime.games]  22 Dec 2021  Xbox One, Xbox Series X|S
# 3314  [Infinite State, eastasiasoft]  21 Dec 2021  Xbox One, Xbox Series X|S
# 3392               [Lightwood Games]  21 Dec 2021  Xbox One, Xbox Series X|S
#
#                      genre hardware notes        medium    size  \
# 1194                Puzzle      NaN   NaN  Digital only  1.38GB
# 1492  Educational & Trivia      NaN   NaN  Digital only  1.32GB
# 3314  Sports, Snowboarding      NaN   NaN  Digital only   707MB
# 3392                Puzzle      NaN   NaN  Digital only   381MB
#
#      completion est          links  \
# 1194            NaN  Official site
# 1492            NaN  Official site
# 3314            NaN  Official site
# 3392      1-2 hours            NaN
#
#                                           features
# 1194                                           NaN
# 1492                                           NaN
# 3314      Smart Delivery, Optimized for Series X|S
# 3392  Smart Delivery, Optimized for Series X|S, 4K

# %%
# para os dados da coluna 'release' com valor 'To be announced'

data_xbox.query('release == "To be announced"')
# data_xbox['release'] = pd.to_datetime(data_xbox['release'])
# data_xbox.head()
# Out:
#       gameid                          name                              web  \
# 1327   10205                Operation Zeta                              NaN
# 2635   10208  Demoniaca: Everlasting Night                              NaN
# 3492   10193              Kraken Academy!!  https://www.kraken-academy.com/
#
#                publisher               developer          release  \
# 1327                 NaN                     NaN  To be announced
# 2635                 NaN                     NaN  To be announced
# 3492  [Fellow Traveller]  [Happy Broccoli Games]  To be announced
#
#                        platform genre hardware notes        medium    size  \
# 1327  Xbox One, Xbox Series X|S   NaN      NaN   NaN  Digital only   844MB
# 2635  Xbox One, Xbox Series X|S   NaN      NaN   NaN  Digital only  2.11GB
# 3492  Xbox One, Xbox Series X|S   NaN      NaN   NaN  Digital only  1.40GB
#
#      completion est          links features
# 1327            NaN            NaN      NaN
# 2635            NaN            NaN      NaN
# 3492            NaN  Official site      NaN

# %%
# após uma breve pesquisa é possível substituir os valores
# Operation Zeta: https://www.xbox.com/pt-BR/games/store/operation-zeta/9P00HTX0XXRV/
# Demoniaca: Everlasting Night: https://www.xbox.com/pt-br/games/store/demoniaca-everlasting-night/9pm3q3dx71p2/
# Kraken Academy!!: https://www.xbox.com/pt-br/games/store/kraken-academy/9p87cgf1tccx/

data_xbox.at[1327, 'release'] = '13 Jan 2022'
data_xbox.at[2635, 'release'] = '11 Jan 2022'
data_xbox.at[3492, 'release'] = '21 Mar 2022'

data_xbox.loc[[1327, 2635, 3492]]
# Out:
#       gameid                          name                              web  \
# 1327   10205                Operation Zeta                              NaN
# 2635   10208  Demoniaca: Everlasting Night                              NaN
# 3492   10193              Kraken Academy!!  https://www.kraken-academy.com/
#
#                publisher               developer      release  \
# 1327                 NaN                     NaN  13 Jan 2022
# 2635                 NaN                     NaN  11 Jan 2022
# 3492  [Fellow Traveller]  [Happy Broccoli Games]  21 Mar 2022
#
#                        platform genre hardware notes        medium    size  \
# 1327  Xbox One, Xbox Series X|S   NaN      NaN   NaN  Digital only   844MB
# 2635  Xbox One, Xbox Series X|S   NaN      NaN   NaN  Digital only  2.11GB
# 3492  Xbox One, Xbox Series X|S   NaN      NaN   NaN  Digital only  1.40GB
#
#      completion est          links features
# 1327            NaN            NaN      NaN
# 2635            NaN            NaN      NaN
# 3492            NaN  Official site      NaN

# %%
# converte-se a coluna 'release' para datetime

data_xbox['release'] = pd.to_datetime(data_xbox['release'])
data_xbox.head()
# Out:
#    gameid                                          name  \
# 0    5530                                             Q
# 1    5819  Q*bert REBOOTED: The XBOX One @!#?@! Edition
# 2    6951                                    Q.U.B.E. 2
# 3    5561                       Q.U.B.E. Director's Cut
# 4    9781                                         Quake
#
#                                        web              publisher  \
# 0  http://liica.co.jp/contents/q/jp/x.html                [liica]
# 1                                      NaN                  [GPC]
# 2      https://www.toxicgames.co.uk/qube2/  [Trapped Nerve Games]
# 3                    http://qube-game.com/         [GRIP Digital]
# 4                                      NaN   [Bethesda Softworks]
#
#                                         developer    release  \
# 0                              [liica, OrangeBox] 2015-06-26
# 1                              [LOOT Interactive] 2016-02-12
# 2                                   [Toxic Games] 2018-03-13
# 3                     [Toxic Games, GRIP Digital] 2015-07-24
# 4  [MachineGames, Nightdive Studios, id Software] 2021-08-19
#
#                                            platform                 genre  \
# 0                                          Xbox One                Puzzle
# 1                         Xbox One, Xbox Series X|S                Action
# 2                         Xbox One, Xbox Series X|S    Puzzle, Platformer
# 3                         Xbox One, Xbox Series X|S    Puzzle, Platformer
# 4  Xbox One, Xbox Series X|S, Windows (Windows 10+)  First Person Shooter
#
#          hardware                                          notes  \
# 0  Kinect Enabled                                        ID@Xbox
# 1             NaN                                        ID@Xbox
# 2             NaN                                        ID@Xbox
# 3             NaN                                        ID@Xbox
# 4          64-Bit  xCloud, Xbox Game Pass, Xbox Game Pass for PC
#
#          medium    size completion est          links  \
# 0  Digital only   515MB   80-100 hours  Official site
# 1  Digital only   501MB            NaN            NaN
# 2  Digital only  2.73GB      6-8 hours  Official site
# 3  Digital only  1.28GB      4-5 hours  Official site
# 4  Digital only  1.25GB      2-3 hours            NaN
#
#                                             features
# 0                                                NaN
# 1                                                NaN
# 2                            Xbox One X Enhanced, 4K
# 3                                                NaN
# 4  Smart Delivery, Optimized for Series X|S, 4K, ...

# %%
data_xbox.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4806 entries, 0 to 4805
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   gameid          4806 non-null   int64
#  1   name            4806 non-null   object
#  2   web             4092 non-null   object
#  3   publisher       4223 non-null   object
#  4   developer       4224 non-null   object
#  5   release         4226 non-null   datetime64[ns]
#  6   platform        4226 non-null   object
#  7   genre           4223 non-null   object
#  8   hardware        461 non-null    object
#  9   notes           2840 non-null   object
#  10  medium          4226 non-null   object
#  11  size            4225 non-null   object
#  12  completion est  3015 non-null   object
#  13  links           3944 non-null   object
#  14  features        1666 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(13)
# memory usage: 563.3+ KB

# %%
# fragmenta-se os valores da coluna 'platform'

data_xbox['platform'] = data_xbox['platform'].str.split(', ')
data_xbox.head()
# Out:
#    gameid                                          name  \
# 0    5530                                             Q
# 1    5819  Q*bert REBOOTED: The XBOX One @!#?@! Edition
# 2    6951                                    Q.U.B.E. 2
# 3    5561                       Q.U.B.E. Director's Cut
# 4    9781                                         Quake
#
#                                        web              publisher  \
# 0  http://liica.co.jp/contents/q/jp/x.html                [liica]
# 1                                      NaN                  [GPC]
# 2      https://www.toxicgames.co.uk/qube2/  [Trapped Nerve Games]
# 3                    http://qube-game.com/         [GRIP Digital]
# 4                                      NaN   [Bethesda Softworks]
#
#                                         developer    release  \
# 0                              [liica, OrangeBox] 2015-06-26
# 1                              [LOOT Interactive] 2016-02-12
# 2                                   [Toxic Games] 2018-03-13
# 3                     [Toxic Games, GRIP Digital] 2015-07-24
# 4  [MachineGames, Nightdive Studios, id Software] 2021-08-19
#
#                                             platform                 genre  \
# 0                                         [Xbox One]                Puzzle
# 1                        [Xbox One, Xbox Series X|S]                Action
# 2                        [Xbox One, Xbox Series X|S]    Puzzle, Platformer
# 3                        [Xbox One, Xbox Series X|S]    Puzzle, Platformer
# 4  [Xbox One, Xbox Series X|S, Windows (Windows 1...  First Person Shooter
#
#          hardware                                          notes  \
# 0  Kinect Enabled                                        ID@Xbox
# 1             NaN                                        ID@Xbox
# 2             NaN                                        ID@Xbox
# 3             NaN                                        ID@Xbox
# 4          64-Bit  xCloud, Xbox Game Pass, Xbox Game Pass for PC
#
#          medium    size completion est          links  \
# 0  Digital only   515MB   80-100 hours  Official site
# 1  Digital only   501MB            NaN            NaN
# 2  Digital only  2.73GB      6-8 hours  Official site
# 3  Digital only  1.28GB      4-5 hours  Official site
# 4  Digital only  1.25GB      2-3 hours            NaN
#
#                                             features
# 0                                                NaN
# 1                                                NaN
# 2                            Xbox One X Enhanced, 4K
# 3                                                NaN
# 4  Smart Delivery, Optimized for Series X|S, 4K, ...

# %%
# fragmenta-se os valores da coluna 'genre'

data_xbox['genre'] = data_xbox['genre'].str.split(', ')

# %%
# fragmenta-se os valores da coluna 'notes'

data_xbox['notes'] = data_xbox['notes'].str.split(', ')

# %%
# para coluna 'size' é necessário distanciar o valor numérico da unidade de armazenamento de dados
# mas para facilitar a iteração substitui-se os valores nulos por 0

data_xbox['size'] = data_xbox['size'].fillna('0MB')
data_xbox.query('size == "0MB"').sample(5)
# Out:
#       gameid                            name  \
# 592    -3198           Tales of the Neon Sea
# 3432   -3833          Kerbal Space Program 2
# 608    -4878  Tasomachi: Behind the Twilight
# 890    -5081               There Is No Light
# 3602   -5029              Lightyear Frontier
#
#                                                     web publisher developer  \
# 592   https://www.bandainamcoent.com/games/tales-of-...       NaN       NaN
# 3432  https://www.kerbalspaceprogram.com/game/kerbal...       NaN       NaN
# 608   https://www.eastasiasoft.com/games/Task-Force-...       NaN       NaN
# 890                              https://thembombs.com/       NaN       NaN
# 3602                                                NaN       NaN       NaN
#
#      release platform genre hardware      notes medium size completion est  \
# 592      NaT      NaN   NaN      NaN        NaN    NaN  0MB            NaN
# 3432     NaT      NaN   NaN      NaN        NaN    NaN  0MB            NaN
# 608      NaT      NaN   NaN      NaN        NaN    NaN  0MB            NaN
# 890      NaT      NaN   NaN      NaN        NaN    NaN  0MB            NaN
# 3602     NaT      NaN   NaN      NaN  [ID@Xbox]    NaN  0MB            NaN
#
#               links features
# 592             NaN      NaN
# 3432  Official site      NaN
# 608             NaN      NaN
# 890             NaN      NaN
# 3602            NaN      NaN

# %%
size_list = list()

for index, size in enumerate(data_xbox['size']):
  for posicao, caractere in enumerate(size):
    if size[posicao].isalpha() == True and size[posicao-1].isdigit() == True:
      size = list(size)
      size.insert(posicao, ' ')
      size_list.append(''.join(size))

size_list[:10]
# Out:
# ['515 MB',
#  '501 MB',
#  '2.73 GB',
#  '1.28 GB',
#  '1.25 GB',
#  '350 MB',
#  '102.56 GB',
#  '0 MB',
#  '5.09 GB',
#  '1.43 GB']

# %%
# os valores foram organizados na colunas 'size'

data_xbox['size'] = size_list
len(data_xbox['size'])
# Out:
# 4806

# %%
size_games = data_xbox['size'].str.split(expand = True)
size_games.head()
# Out:
#       0   1
# 0   515  MB
# 1   501  MB
# 2  2.73  GB
# 3  1.28  GB
# 4  1.25  GB

# %%
# apaga-se a 'velha' coluna 'size' e define-se duas novas colunas com o valor numérico do tamanho do arquivo e a unidade de armazenamento

data_xbox.pop('size')
data_xbox['size'] = size_games[0]
data_xbox['unit'] = size_games[1]
data_xbox.head(2)
# Out:
#    gameid                                          name  \
# 0    5530                                             Q
# 1    5819  Q*bert REBOOTED: The XBOX One @!#?@! Edition
#
#                                        web publisher           developer  \
# 0  http://liica.co.jp/contents/q/jp/x.html   [liica]  [liica, OrangeBox]
# 1                                      NaN     [GPC]  [LOOT Interactive]
#
#      release                     platform     genre        hardware  \
# 0 2015-06-26                   [Xbox One]  [Puzzle]  Kinect Enabled
# 1 2016-02-12  [Xbox One, Xbox Series X|S]  [Action]             NaN
#
#        notes        medium completion est          links features size unit
# 0  [ID@Xbox]  Digital only   80-100 hours  Official site      NaN  515   MB
# 1  [ID@Xbox]  Digital only            NaN            NaN      NaN  501   MB

# %%
# converte-se a coluna 'size' de object para float

data_xbox['size'] = data_xbox['size'].astype(float)
data_xbox.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4806 entries, 0 to 4805
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   gameid          4806 non-null   int64
#  1   name            4806 non-null   object
#  2   web             4092 non-null   object
#  3   publisher       4223 non-null   object
#  4   developer       4224 non-null   object
#  5   release         4226 non-null   datetime64[ns]
#  6   platform        4226 non-null   object
#  7   genre           4223 non-null   object
#  8   hardware        461 non-null    object
#  9   notes           2840 non-null   object
#  10  medium          4226 non-null   object
#  11  completion est  3015 non-null   object
#  12  links           3944 non-null   object
#  13  features        1666 non-null   object
#  14  size            4806 non-null   float64
#  15  unit            4806 non-null   object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(13)
# memory usage: 600.9+ KB

# %%
# também converte-se os valores para unidade de armazenamento GB, de forma a padronizar as colunas

armazenamento_gb = list()


for index, unidade in enumerate(data_xbox['unit']):
  if unidade == 'MB':
    armazenamento_em_gb = float(data_xbox['size'][index])/1000
    armazenamento_gb.append(armazenamento_em_gb)

len(armazenamento_gb)
# Out:
# 2184

# %%
contador = 0 

for index, unidade in enumerate(data_xbox['unit']):
  if unidade == 'MB':
    data_xbox['size'][index] = armazenamento_gb[contador]
    contador += 1

data_xbox.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#    gameid                                          name  \
# 0    5530                                             Q
# 1    5819  Q*bert REBOOTED: The XBOX One @!#?@! Edition
# 2    6951                                    Q.U.B.E. 2
# 3    5561                       Q.U.B.E. Director's Cut
# 4    9781                                         Quake
#
#                                        web              publisher  \
# 0  http://liica.co.jp/contents/q/jp/x.html                [liica]
# 1                                      NaN                  [GPC]
# 2      https://www.toxicgames.co.uk/qube2/  [Trapped Nerve Games]
# 3                    http://qube-game.com/         [GRIP Digital]
# 4                                      NaN   [Bethesda Softworks]
#
#                                         developer    release  \
# 0                              [liica, OrangeBox] 2015-06-26
# 1                              [LOOT Interactive] 2016-02-12
# 2                                   [Toxic Games] 2018-03-13
# 3                     [Toxic Games, GRIP Digital] 2015-07-24
# 4  [MachineGames, Nightdive Studios, id Software] 2021-08-19
#
#                                             platform                   genre  \
# 0                                         [Xbox One]                [Puzzle]
# 1                        [Xbox One, Xbox Series X|S]                [Action]
# 2                        [Xbox One, Xbox Series X|S]    [Puzzle, Platformer]
# 3                        [Xbox One, Xbox Series X|S]    [Puzzle, Platformer]
# 4  [Xbox One, Xbox Series X|S, Windows (Windows 1...  [First Person Shooter]
#
#          hardware                                            notes  \
# 0  Kinect Enabled                                        [ID@Xbox]
# 1             NaN                                        [ID@Xbox]
# 2             NaN                                        [ID@Xbox]
# 3             NaN                                        [ID@Xbox]
# 4          64-Bit  [xCloud, Xbox Game Pass, Xbox Game Pass for PC]
#
#          medium completion est          links  \
# 0  Digital only   80-100 hours  Official site
# 1  Digital only            NaN            NaN
# 2  Digital only      6-8 hours  Official site
# 3  Digital only      4-5 hours  Official site
# 4  Digital only      2-3 hours            NaN
#
#                                             features   size unit
# 0                                                NaN  0.515   MB
# 1                                                NaN  0.501   MB
# 2                            Xbox One X Enhanced, 4K  2.730   GB
# 3                                                NaN  1.280   GB
# 4  Smart Delivery, Optimized for Series X|S, 4K, ...  1.250   GB

# %%
data_xbox.columns
# Out:
# Index(['gameid', 'name', 'web', 'publisher', 'developer', 'release',
#        'platform', 'genre', 'hardware', 'notes', 'medium', 'completion est',
#        'links', 'features', 'size', 'unit'],
#       dtype='object')

# %%
#revome-se a coluna 'unit' e renomeia-se a coluna 'size'

data_xbox.pop('unit')
data_xbox.columns = ['gameid', 'name', 'web', 'publisher', 'developer', 'release', 'platform', 'genre', 'hardware', 'notes', 
                     'medium', 'completion est', 'links', 'features', 'size (GB)']
data_xbox.head()
# Out:
#    gameid                                          name  \
# 0    5530                                             Q
# 1    5819  Q*bert REBOOTED: The XBOX One @!#?@! Edition
# 2    6951                                    Q.U.B.E. 2
# 3    5561                       Q.U.B.E. Director's Cut
# 4    9781                                         Quake
#
#                                        web              publisher  \
# 0  http://liica.co.jp/contents/q/jp/x.html                [liica]
# 1                                      NaN                  [GPC]
# 2      https://www.toxicgames.co.uk/qube2/  [Trapped Nerve Games]
# 3                    http://qube-game.com/         [GRIP Digital]
# 4                                      NaN   [Bethesda Softworks]
#
#                                         developer    release  \
# 0                              [liica, OrangeBox] 2015-06-26
# 1                              [LOOT Interactive] 2016-02-12
# 2                                   [Toxic Games] 2018-03-13
# 3                     [Toxic Games, GRIP Digital] 2015-07-24
# 4  [MachineGames, Nightdive Studios, id Software] 2021-08-19
#
#                                             platform                   genre  \
# 0                                         [Xbox One]                [Puzzle]
# 1                        [Xbox One, Xbox Series X|S]                [Action]
# 2                        [Xbox One, Xbox Series X|S]    [Puzzle, Platformer]
# 3                        [Xbox One, Xbox Series X|S]    [Puzzle, Platformer]
# 4  [Xbox One, Xbox Series X|S, Windows (Windows 1...  [First Person Shooter]
#
#          hardware                                            notes  \
# 0  Kinect Enabled                                        [ID@Xbox]
# 1             NaN                                        [ID@Xbox]
# 2             NaN                                        [ID@Xbox]
# 3             NaN                                        [ID@Xbox]
# 4          64-Bit  [xCloud, Xbox Game Pass, Xbox Game Pass for PC]
#
#          medium completion est          links  \
# 0  Digital only   80-100 hours  Official site
# 1  Digital only            NaN            NaN
# 2  Digital only      6-8 hours  Official site
# 3  Digital only      4-5 hours  Official site
# 4  Digital only      2-3 hours            NaN
#
#                                             features  size (GB)
# 0                                                NaN      0.515
# 1                                                NaN      0.501
# 2                            Xbox One X Enhanced, 4K      2.730
# 3                                                NaN      1.280
# 4  Smart Delivery, Optimized for Series X|S, 4K, ...      1.250

# %%
# quanto a coluna 'medium', os valores existentes 

data_xbox['medium'].unique()
# Out:
# array(['Digital only', 'Physical and Digital', nan, 'Physical only'],
#       dtype=object)

# %%
# estabelecendo os valores 'Digital', 'Physical' e 'Digital, Physical'

contador = 0

for index, medium in enumerate(data_xbox['medium']):
  try:
    if medium == 'Digital only':
      data_xbox['medium'][index] = 'Digital'
    elif medium == 'Physical only':
      data_xbox['medium'][index] = 'Physical'
    elif medium == None:
      pass
    else:
      data_xbox['medium'][index] = 'Digital, Physical'
  except TypeError:
    pass
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
# separando os valores quando este for composto por mais de um elemento

data_xbox['medium'] = data_xbox['medium'].str.split(', ')
data_xbox.sample(20)
# Out:
#       gameid                                       name  \
# 2572    5414                 Dead or Alive 5 Last Round
# 2897    7209                                 Fernz Gate
# 1043    7991                                  Tropico 6
# 2094    8850  Shantae: Risky's Revenge - Director's Cut
# 1938    7199                      Asemblance: Oversight
# 2221    9525                             Song of Horror
# 849     8523                          The Taller I Grow
# 3396    5257                            Just Dance 2015
# 337     6658                         RAID: World War II
# 898     7327                      Think of the Children
# 4184    9623                        Blaster Master Zero
# 3376    5888      Joe Dever's Lone Wolf Console Edition
# 748     7058    The Infectious Madness of Doctor Dekker
# 232     7223                                       Elea
# 1109   -5108                                      Ukiyo
# 1436    6111                              Perfect Woman
# 2159    9141                                   Skycadia
# 1676    6955          ACA NEOGEO REAL BOUT FATAL FURY 2
# 2434    6746                         Super Lucky's Tale
# 3985    6072                                     Valley
#
#                                                     web  \
# 2572  http://www.teamninja-studio.com/doa5/lastround...
# 2897     https://www.kemco.jp/sp/games/fg/en/index.html
# 1043                  http://www.worldoftropico.com/en/
# 2094  https://wayforward.com/games/shantae-riskys-re...
# 1938                   http://asemblance.com/index.html
# 2221        https://www.raisergames.com/song-of-horror/
# 849    https://noobles-studio.itch.io/the-taller-i-grow
# 3396  https://www.ubisoft.com/en-us/game/just-dance-...
# 337                       http://www.raidworldwar2.com/
# 898                  http://thinkofthechildrengame.com/
# 4184             http://blastermaster-zero.com/en/zero/
# 3376   https://505games.com/games/joe-devers-lone-wolf/
# 748                        http://www.doctordekker.com/
# 232                         http://www.projectelea.com/
# 1109                          https://seaknot.dev/ukiyo
# 1436                   http://www.perfectwomangame.com/
# 2159                                                NaN
# 1676  http://www.hamster.co.jp/american_hamster/arca...
# 2434                    http://www.superluckystale.com/
# 3985                      http://www.valleythegame.com/
#
#                             publisher                     developer  \
# 2572                     [KOEI TECMO]                  [Team Ninja]
# 2897                          [KEMCO]                  [EXE-CREATE]
# 1043                  [Kalypso Media]        [Limbic Entertainment]
# 2094        [WayForward Technologies]     [WayForward Technologies]
# 1938                   [Nilo Studios]                [Nilo Studios]
# 2221                   [Raiser Games]              [Protocol Games]
# 849                  [Noobles Studio]              [Noobles Studio]
# 3396                        [Ubisoft]               [Ubisoft Paris]
# 337   [Starbreeze Studios, 505 Games]              [Lion Game Lion]
# 898                [Fellow Traveller]           [Jammed Up Studios]
# 4184                   [Inti CREATES]                [Inti CREATES]
# 3376                      [505 Games]                 [Forge Reply]
# 748               [Wales Interactive]            [D’Avekki Studios]
# 232                        [SOEDESCO]                      [Kyodai]
# 1109                              NaN                           NaN
# 1436     [Peter Lu & Lea Schönfelder]  [Peter Lu & Lea Schönfelder]
# 2159                   [Studio Nisse]                [Studio Nisse]
# 1676                        [Hamster]                [SNK, Hamster]
# 2434              [Xbox Game Studios]             [Playful Studios]
# 3985              [Blue Isle Studios]           [Blue Isle Studios]
#
#         release                                           platform  \
# 2572 2015-02-20                        [Xbox One, Xbox Series X|S]
# 2897 2018-08-15  [Xbox One, Xbox Series X|S, Windows (Windows 1...
# 1043 2019-09-27                        [Xbox One, Xbox Series X|S]
# 2094 2020-10-15  [Xbox One, Xbox Series X|S, Windows (Windows 1...
# 1938 2018-08-03                        [Xbox One, Xbox Series X|S]
# 2221 2021-05-28                        [Xbox One, Xbox Series X|S]
# 849  2020-05-22                        [Xbox One, Xbox Series X|S]
# 3396 2014-10-21                        [Xbox One, Xbox Series X|S]
# 337  2017-10-10                        [Xbox One, Xbox Series X|S]
# 898  2018-09-26                        [Xbox One, Xbox Series X|S]
# 4184 2021-07-01                        [Xbox One, Xbox Series X|S]
# 3376 2016-03-16                        [Xbox One, Xbox Series X|S]
# 748  2018-06-05                        [Xbox One, Xbox Series X|S]
# 232  2018-09-06                        [Xbox One, Xbox Series X|S]
# 1109        NaT                                                NaN
# 1436 2016-09-14                                         [Xbox One]
# 2159 2021-01-22                        [Xbox One, Xbox Series X|S]
# 1676 2018-03-08                        [Xbox One, Xbox Series X|S]
# 2434 2017-11-07  [Xbox One, Xbox Series X|S, Windows (Windows 1...
# 3985 2016-08-24                        [Xbox One, Xbox Series X|S]
#
#                            genre                         hardware  \
# 2572                  [Fighting]                              NaN
# 2897  [Role Playing, Turn Based]                              NaN
# 1043    [Simulation, Management]                              NaN
# 2094  [Metroidvania, Platformer]                           64-Bit
# 1938                 [Adventure]                              NaN
# 2221           [Survival Horror]                              NaN
# 849         [Puzzle, Platformer]                              NaN
# 3396                     [Dance]  Kinect Enabled, Kinect Required
# 337       [First Person Shooter]                              NaN
# 898                     [Action]                              NaN
# 4184  [Metroidvania, Platformer]                              NaN
# 3376  [Role Playing, Turn Based]                              NaN
# 748               [Visual Novel]                              NaN
# 232                  [Adventure]                              NaN
# 1109                         NaN                              NaN
# 1436                    [Puzzle]                  Kinect Required
# 2159              [Shoot 'em up]                              NaN
# 1676                  [Fighting]                              NaN
# 2434                [Platformer]                           64-Bit
# 3985                [Platformer]                              NaN
#
#                                         notes               medium  \
# 2572                                      NaN  [Digital, Physical]
# 2897                                [ID@Xbox]            [Digital]
# 1043        [ID@Xbox, xCloud, Xbox Game Pass]  [Digital, Physical]
# 2094                                [ID@Xbox]            [Digital]
# 1938                                [ID@Xbox]            [Digital]
# 2221                                [ID@Xbox]            [Digital]
# 849                                 [ID@Xbox]            [Digital]
# 3396                                      NaN  [Digital, Physical]
# 337                                 [ID@Xbox]  [Digital, Physical]
# 898                                 [ID@Xbox]            [Digital]
# 4184                                [ID@Xbox]            [Digital]
# 3376                                      NaN            [Digital]
# 748                                 [ID@Xbox]            [Digital]
# 232                                       NaN            [Digital]
# 1109                                      NaN  [Digital, Physical]
# 1436                                [ID@Xbox]            [Digital]
# 2159                                [ID@Xbox]            [Digital]
# 1676                                      NaN            [Digital]
# 2434  [Xbox Game Pass, Xbox Game Pass for PC]  [Digital, Physical]
# 3985                                [ID@Xbox]            [Digital]
#
#                        completion est          links  \
# 2572                      15-20 hours  Official site
# 2897                      20-25 hours  Official site
# 1043                      50-60 hours  Official site
# 2094                       8-10 hours  Official site
# 1938                         0-1 hour  Official site
# 2221                              NaN  Official site
# 849                         1-2 hours  Official site
# 3396                     80-100 hours  Official site
# 337                     120-150 hours  Official site
# 898                               NaN  Official site
# 4184                              NaN  Official site
# 3376                              NaN  Official site
# 748                        8-10 hours  Official site
# 232                         3-4 hours  Official site
# 1109                              NaN  Official site
# 1436                              NaN  Official site
# 2159                        5-6 hours            NaN
# 1676                        1-2 hours  Official site
# 2434  8-10 hours (excludes DLC packs)  Official site
# 3985                       8-10 hours  Official site
#
#                                                features  size (GB)
# 2572                                                NaN     10.380
# 2897                                 Xbox Play Anywhere      0.726
# 1043  Xbox One X Enhanced, 4K, xCloud Touch Controls...     13.330
# 2094                                 Xbox Play Anywhere      0.277
# 1938                                                NaN      3.950
# 2221                                                NaN     10.550
# 849                                                 NaN      0.103
# 3396                                                NaN     15.610
# 337                                                 NaN      7.730
# 898                                                 NaN      0.862
# 4184           Smart Delivery, Optimized for Series X|S      0.497
# 3376                                                NaN      3.130
# 748                                                 NaN      9.900
# 232                                 Xbox One X Enhanced      4.960
# 1109                                                NaN      0.000
# 1436                                                NaN      0.263
# 2159  Xbox One X Enhanced, Optimized for Series X|S,...      0.338
# 1676                                                NaN      0.261
# 2434        Xbox One X Enhanced, Xbox Play Anywhere, 4K     10.300
# 3985                                                NaN      4.420

# %%
data_xbox[data_xbox['medium'].isna()]
# Out:
# Empty DataFrame
# Columns: [gameid, name, web, publisher, developer, release, platform, genre, hardware, notes, medium, completion est, links, features, size (GB)]
# Index: []
